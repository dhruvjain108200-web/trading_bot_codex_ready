# %% [markdown]
# # Trading Bot Runner (Colab)
# This notebook mounts Drive, bootstraps the project, and starts the bot.

# %%
from google.colab import drive
drive.mount('/content/drive')

PROJECT_ROOT = '/content/drive/MyDrive/trading_bot'
print('PROJECT_ROOT:', PROJECT_ROOT)

# %%
# Bootstrap
import sys
sys.path.append(PROJECT_ROOT)

from src.bootstrap import bootstrap
ctx = bootstrap(PROJECT_ROOT)
print('Bootstrapped:', {k: ctx[k] for k in ['project_root','secrets_loaded']})

# %%
# Start bot (placeholder until Supervisor is implemented)
from src.main import run_bot
run_bot(PROJECT_ROOT, mode='paper')
